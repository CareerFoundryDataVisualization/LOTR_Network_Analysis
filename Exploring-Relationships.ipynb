# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# import dataframes
path = r'/Users/samira/Desktop/6 Advanced Analytics and Dashboard Design/'
df_times = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'timesData.csv'))
df_shanghai = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'shanghaiData.csv'))
df_cwur = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'cwurData.csv'))

# %%
matplotlib.__version__
# Out:
# '3.5.1'

# %%
df_times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# 2     United States of America      97.8          82.3      91.4       99.9
# 3     United States of America      98.3          29.5      98.1       99.2
# 4     United States of America      90.9          70.3      95.4       99.9
# ...                        ...       ...           ...       ...        ...
# 2598               South Korea      18.6          24.3      10.9       26.5
# 2599                    Turkey      14.5          14.9       7.6       19.3
# 2600                     Japan      24.0          16.1      10.2       36.4
# 2601                     Japan      20.1          23.3      16.0       13.5
# 2602                    Taiwan      16.2          17.7      18.3       28.6
#
#      income total_score num_students  student_staff_ratio  \
# 0      34.5        96.1       20,152                  8.9
# 1      83.7        96.0        2,243                  6.9
# 2      87.5        95.6       11,074                  9.0
# 3      64.3        94.3       15,596                  7.8
# 4         -        94.2        7,929                  8.4
# ...     ...         ...          ...                  ...
# 2598   35.4           -       21,958                 15.3
# 2599   44.0           -       31,268                 28.7
# 2600   37.9           -        4,122                  3.7
# 2601   40.4           -       10,117                 12.1
# 2602   39.8           -        8,663                 20.6
#
#      international_students female_male_ratio  year
# 0                       25%               NaN  2011
# 1                       27%           33 : 67  2011
# 2                       33%           37 : 63  2011
# 3                       22%           42 : 58  2011
# 4                       27%           45 : 55  2011
# ...                     ...               ...   ...
# 2598                     3%           48 : 52  2016
# 2599                     2%           36 : 64  2016
# 2600                     3%               NaN  2016
# 2601                     8%           28 : 72  2016
# 2602                     4%           43 : 57  2016
#
# [2603 rows x 14 columns]

# %%
df_shanghai
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 2             3                          Stanford University             2
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# ...         ...                                          ...           ...
# 4892    401-500                        University of Trieste         11-20
# 4893    401-500                       University of Zaragoza          9-13
# 4894    401-500                        Utah State University       126-146
# 4895    401-500              Vienna University of Technology           4-6
# 4896    401-500                       Wake Forest University       126-146
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# 0           100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1            73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2            73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3            72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4            70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005
# ...           ...     ...    ...    ...    ...    ...   ...   ...
# 4892          NaN     0.0    0.0    5.0   10.9   25.1  20.1  2015
# 4893          NaN     0.0    0.0    7.6    5.1   33.3  13.1  2015
# 4894          NaN    13.6    0.0    3.6   10.8   25.1  15.5  2015
# 4895          NaN     0.0    0.0    0.0   12.2   28.8  22.9  2015
# 4896          NaN     0.0    0.0   14.9    7.5   25.0  11.9  2015
#
# [4897 rows x 11 columns]

# %%
df_cwur
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 3          50   86.17  2012
# 4          18   85.21  2012
# ...       ...     ...   ...
# 2195      816   44.03  2015
# 2196      871   44.03  2015
# 2197      824   44.03  2015
# 2198      651   44.02  2015
# 2199      547   44.02  2015
#
# [2200 rows x 14 columns]

# %% [markdown]
# #### Correlation matrix heatmap

# %%
# correlation matrix
df_times.corr()
# Out:
#                      teaching  research  citations  student_staff_ratio  \
# teaching             1.000000  0.913120   0.503867            -0.282630
# research             0.913120  1.000000   0.525264            -0.198841
# citations            0.503867  0.525264   1.000000            -0.137737
# student_staff_ratio -0.282630 -0.198841  -0.137737             1.000000
# year                -0.278108 -0.274451  -0.173544             0.060728
#
#                          year
# teaching            -0.278108
# research            -0.274451
# citations           -0.173544
# student_staff_ratio  0.060728
# year                 1.000000

# %%
sub_1 = df_times[['world_rank', 'country', 'teaching', 'international', 'research', 'citations', 'income', 'num_students', 'student_staff_ratio', 'international_students', 'female_male_ratio']]

# %%
# deleting all rows where theres a "-" in world_rank in sub_1
sub_2 = sub_1.loc[sub_1['world_rank'].str.contains("-", case=False)]

# %%
sub_2
# Out:
#      world_rank                   country  teaching international  research  \
# 400     201-225                     Spain      33.7          45.9      27.9
# 401     201-225                    Turkey      27.9          48.5      22.3
# 402     201-225            United Kingdom      28.9          67.8      34.0
# 403     201-225  United States of America      24.6          38.4      22.8
# 404     201-225                     Japan      45.5          21.2      39.2
# ...         ...                       ...       ...           ...       ...
# 2598    601-800               South Korea      18.6          24.3      10.9
# 2599    601-800                    Turkey      14.5          14.9       7.6
# 2600    601-800                     Japan      24.0          16.1      10.2
# 2601    601-800                     Japan      20.1          23.3      16.0
# 2602    601-800                    Taiwan      16.2          17.7      18.3
#
#       citations income num_students  student_staff_ratio  \
# 400        57.9   37.0       30,538                 12.3
# 401        60.8   29.4          NaN                  NaN
# 402        51.7   35.5       23,347                 13.1
# 403        63.7   99.4        5,287                 18.2
# 404        43.8   33.1       15,529                  7.9
# ...         ...    ...          ...                  ...
# 2598       26.5   35.4       21,958                 15.3
# 2599       19.3   44.0       31,268                 28.7
# 2600       36.4   37.9        4,122                  3.7
# 2601       13.5   40.4       10,117                 12.1
# 2602       28.6   39.8        8,663                 20.6
#
#      international_students female_male_ratio
# 400                     10%           59 : 41
# 401                     NaN               NaN
# 402                     23%           57 : 43
# 403                     12%           26 : 74
# 404                     10%           29 : 71
# ...                     ...               ...
# 2598                     3%           48 : 52
# 2599                     2%           36 : 64
# 2600                     3%               NaN
# 2601                     8%           28 : 72
# 2602                     4%           43 : 57
#
# [1402 rows x 11 columns]

# %%
# save dataframe in sub_clean - only the rows where 'world_rank' DOESN't contain "-"
sub_clean = sub_1[sub_1['world_rank'].str.contains("-", case=False) == False]

# %%
# check if all 'world_rank' entries that contain "-" were deleted
sub_clean.loc[sub_clean['world_rank'].str.contains("-", case=False)]
# Out:
# Empty DataFrame
# Columns: [world_rank, country, teaching, international, research, citations, income, num_students, student_staff_ratio, international_students, female_male_ratio]
# Index: []

# %%
# see where 'world_rank' = "=39"
sub_clean.loc[sub_clean['world_rank'].str.contains("=", case=False)]
# Out:
#      world_rank                   country  teaching international  research  \
# 1841        =39  United States of America      56.9          42.9      69.8
# 1842        =39  United States of America      52.6          61.5      66.0
# 1846        =44  United States of America      60.1          58.4      72.7
# 1847        =44                 Hong Kong      64.6          99.5      72.8
# 1849        =47                     China      73.3          39.5      83.0
# ...         ...                       ...       ...           ...       ...
# 1993       =190  United States of America      34.1          60.0      29.3
# 1995       =193                Luxembourg      25.0          99.8      26.7
# 1996       =193  United States of America      49.4          47.8      52.4
# 1998       =196            United Kingdom      30.9          84.3      27.5
# 1999       =196            United Kingdom      25.6          69.5      18.1
#
#       citations income num_students  student_staff_ratio  \
# 1841       98.7   56.7       27,233                  6.5
# 1842       99.2   90.4       22,020                 27.3
# 1846       84.3   57.3       35,364                 13.9
# 1847       70.1   53.7       19,835                 17.6
# 1849       58.8  100.0       39,763                 13.7
# ...         ...    ...          ...                  ...
# 1993       83.3   46.8       13,216                 17.4
# 1995       84.8   38.1        5,144                 15.9
# 1996       47.1   46.4       50,657                 21.4
# 1998       81.5   34.7       20,174                 15.2
# 1999      100.0   37.7        2,958                 13.4
#
#      international_students female_male_ratio
# 1841                    11%           48 : 52
# 1842                    11%           52 : 48
# 1846                    13%           54 : 46
# 1847                    38%           53 : 47
# 1849                    10%           32 : 68
# ...                     ...               ...
# 1993                    19%           54 : 46
# 1995                    52%           50 : 50
# 1996                     9%           47 : 53
# 1998                    29%           50 : 50
# 1999                    17%           61 : 39
#
# [89 rows x 11 columns]

# %%
# save dataframe in sub_clean - only the rows where 'world_rank' DOESN't contain "="
sub_clean = sub_clean[sub_clean['world_rank'].str.contains("=", case=False) == False]

# %%
# see where 'world_rank' = "=39"
sub_clean.loc[sub_clean['world_rank'].str.contains("=", case=False)]
# Out:
# Empty DataFrame
# Columns: [world_rank, country, teaching, international, research, citations, income, num_students, student_staff_ratio, international_students, female_male_ratio]
# Index: []

# %%
# add labels, a legend, and change the size of the heatmap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(sub_clean.corr(), fignum=f.number) # type of plot
plt.xticks(range(sub_clean.shape[1]), sub_clean.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(sub_clean.shape[1]), sub_clean.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix Times', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Times')

# %% [markdown]
# #### Observation
# What's interesting is that there are some strong negative realtionships between international and world_rank, country, teaching. Also between teaching and world_rank/country ranking there is - as expected - a positive relationship. And world_rank and country ranking have almost no relationship, which also makes sense as a university can be the best of a country which doesn't mean that it's best in the world too.

# %% [markdown]
# #### Scatterplot

# %%
sns.lmplot(x = 'world_rank', y = 'teaching', data = sub_clean)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 sns.lmplot(x = 'world_rank', y = 'teaching', data = sub_clean)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:645, in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     636 # Draw the regression plot on each facet
#     637 regplot_kws = dict(
#     638     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
#     639     scatter=scatter, fit_reg=fit_reg, ci=ci, n_boot=n_boot, units=units,
#    (...)
#     643     scatter_kws=scatter_kws, line_kws=line_kws,
#     644 )
# --> 645 facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     646 facets.set_axis_labels(x, y)
#     648 # Add a legend
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:777, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     774     kwargs["data"] = data_ijk
#     776     # Draw the plot
# --> 777     self._facet_plot(func, ax, args, kwargs)
#     779 # For axis labels, prefer to use positional args for backcompat
#     780 # but also extract the x/y kwargs and use if no corresponding arg
#     781 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:806, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804     plot_args = []
#     805     plot_kwargs["ax"] = ax
# --> 806 func(*plot_args, **plot_kwargs)
#     808 # Sort out the supporting information
#     809 self._update_legend_data(ax)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:201, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     199         else:
#     200             x_min, x_max = ax.get_xlim()
# --> 201     grid = np.linspace(x_min, x_max, 100)
#     202 ci = self.ci
#     204 # Fit the regression
#
# File <__array_function__ internals>:5, in linspace(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/function_base.py:127, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     123 div = (num - 1) if endpoint else num
#     125 # Convert float/complex array scalars to float, gh-3504
#     126 # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 127 start = asanyarray(start) * 1.0
#     128 stop  = asanyarray(stop)  * 1.0
#     130 dt = result_type(start, stop, float(num))
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U1'), dtype('float64')) -> None

# %% [markdown]
# #### Observation
# We can see that the higher the ranking is (meaning lower the number) the higher the university is scored in teaching. What is particularly interesting is that there are a few unis that that have a high score in teaching but a rather low ranking in the world.

# %% [markdown]
# #### Pair plot

# %%
g = sns.pairplot(sub_clean)

# %% [markdown]
# #### Observation
# There appears to be a strong relationship between teaching and research. The other relationships seem rather weak.

# %% [markdown]
# #### Categorical plot

# %%
sns.histplot(sub_clean['teaching'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='teaching', ylabel='Count'>

# %%
# converting 'world_rank' to int
sub_clean = sub_clean.astype({'world_rank':'int'})

# %%
sub_clean.loc[sub_clean['world_rank'] <= 3, 'world_rank_position'] = 'Top 3'

# %%
sub_clean.loc[(sub_clean['world_rank'] > 3) & (sub_clean['world_rank'] <= 10), 'world_rank_position'] = 'Top 10'

# %%
sub_clean.loc[(sub_clean['world_rank'] > 10) & (sub_clean['world_rank'] <= 20), 'world_rank_position'] = 'Top 20'

# %%
sub_clean.loc[(sub_clean['world_rank'] > 20) & (sub_clean['world_rank'] <= 50), 'world_rank_position'] = 'Top 50'

# %%
sub_clean.loc[(sub_clean['world_rank'] > 50) & (sub_clean['world_rank'] <= 100), 'world_rank_position'] = 'Top 100'

# %%
sub_clean['world_rank_position'].value_counts(dropna = False)
# Out:
# NaN        536
# Top 100    281
# Top 50     175
# Top 20      60
# Top 10      42
# Top 3       18
# Name: world_rank_position, dtype: int64

# %%
sns.set(style="ticks")
g = sns.catplot(x="world_rank", y="teaching", hue="world_rank_position", data=sub_clean)

# %% [markdown]
# #### Observation
# As expected we can see that the higher the score in teaching is the higher the university scores overall (`world_rank`). The coloring of the`world_rank_position` helps to read the plot faster.

# %% [markdown]
# #### New questions
# - Is there a relation between female_male_ratio and world ranking of a uni?
# #### Hypothesis
# - The higher the ranking in teaching the higher the ranking overall.
# - The higher the ranking in teaching the higher the ranking in research.
